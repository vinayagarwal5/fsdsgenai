# %%
l = []  
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l1 = [10, 20, 30] 
l1
# Out:
# [10, 20, 30]

# %%
len(l1)
# Out:
# 3

# %%
l1 = [10, 20, 30] 
l1
# Out:
# [10, 20, 30]

# %%
l1 = [10, 20, 30] 
l1
# Out:
# [10, 20, 30]

# %%
l1.append(40)
l1.append(50)
l1.append(60)
l1.append(10)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l1.append(70)

# %%
l1.append(['a', 'b', 'c'])

# %%
l2 = [34, 5.3, 'prakash', 1+2j, True] 
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2823590391616
# 2823590515520
# 2823590456000

# %%
print(type(l))
print(type(l1))
print(type(l2))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, 70, ['a', 'b', 'c']]

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3 = l2.copy()

# %%
print(id(l2))
print(id(l3))
# Out:
# 2823590456000
# 2823590545024

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, 70, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
len(l3)
# Out:
# 5

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
len(l3)
# Out:
# 0

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, 70, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2.count(5.3)
# Out:
# 1

# %%
m1 = np.random.randint(1,10,(9,9))
print(m1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 m1 = np.random.randint(1,10,(9,9))
#       2 print(m1)
#
# NameError: name 'np' is not defined

# %%
import matplotlib.pyplot as plt # matplotlib for visualization

# %%
from PIL import Image # python Imageing library

# %%
ele_img = Image.open(r'C:\Users\vinay agrawal\FSDS_PROJECT\elee.jpg')

# %%
ele_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x681>

# %%
type(ele_img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
ele_arr = np.asarray(ele_img)
ele_arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 ele_arr = np.asarray(ele_img)
#       2 ele_arr
#
# NameError: name 'np' is not defined
