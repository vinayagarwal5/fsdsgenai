# %% [raw]
# - list
# - tuple
# - set
# - dict
# - range

# %%
l = []  
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l1 = [10, 20, 30] 
l1
# Out:
# [10, 20, 30]

# %%
len(l1)
# Out:
# 3

# %%
l1
# Out:
# [10, 20, 30]

# %%
l1.append(40)
l1.append(50)
l1.append(60)
l1.append(10)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
len(l1)
# Out:
# 7

# %%
l1.append(70, 80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l1.append(70, 80)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l1.append(['a', 'b', 'c'])

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l2 = [34, 5.3, 'prakash', 1+2j, True] 
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 0
# 8
# 5

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2439211059584
# 2439211059776
# 2439233893952

# %%
print(type(l))
print(type(l1))
print(type(l2))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
# list membership 

10 in l1
# Out:
# True

# %%
['a', 'b', 'c'] in l1
# Out:
# True

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
100 in l1
# Out:
# False

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3 = l2.copy()

# %%
l3
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
print(id(l2))
print(id(l3))
# Out:
# 2439233893952
# 2439233549184

# %%
print(l)
print(l1)
print(l2)
print(l3)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
len(l3)
# Out:
# 5

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
len(l3)
# Out:
# 0

# %%
del l3

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2.count(5.3)
# Out:
# 1

# %%
l1.count(10)
# Out:
# 2

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[:]
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[-1]
# Out:
# ['a', 'b', 'c']

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 l1[100]
#
# IndexError: list index out of range

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[4:]
# Out:
# [50, 60, 10, ['a', 'b', 'c']]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[3:-1]
# Out:
# [40, 50, 60, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[0:10:3]
# Out:
# [10, 40, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::1]
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::2]
# Out:
# [10, 30, 50, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::3]
# Out:
# [10, 40, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1.count(10)
# Out:
# 2

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::-1]
# Out:
# [['a', 'b', 'c'], 10, 60, 50, 40, 30, 20, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::-2]
# Out:
# [['a', 'b', 'c'], 60, 40, 20]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[::-3]
# Out:
# [['a', 'b', 'c'], 50, 20]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[4:-3]
# Out:
# [50]

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 100

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, ['a', 'b', 'c']]

# %%
l1[-1] = 'prakash senapati'
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati']

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati']

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati']
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l.extend(l2)

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, 'prakash', (1+2j), True]
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati']
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l.extend(l1) 
l
# Out:
# [34,
#  5.3,
#  'prakash',
#  (1+2j),
#  True,
#  100,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  'prakash senapati']

# %%
l.index('prakash')
# Out:
# 2

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati']

# %%
l1.append(10)

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati', 10]

# %%
l1.index(10)
# Out:
# 6

# %%
l1
# Out:
# [100, 20, 30, 40, 50, 60, 10, 'prakash senapati', 10]

# %%
l1.insert(2, 25)

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10, 'prakash senapati', 10]

# %%
l1.pop()
# Out:
# 10

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10, 'prakash senapati']

# %%
l1.pop()
# Out:
# 'prakash senapati'

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10]

# %%
l
# Out:
# [34,
#  5.3,
#  'prakash',
#  (1+2j),
#  True,
#  100,
#  20,
#  30,
#  40,
#  50,
#  60,
#  10,
#  'prakash senapati']

# %%
l.pop()
# Out:
# 'prakash senapati'

# %%
l.pop()
# Out:
# 10

# %%
l
# Out:
# [34, 5.3, 'prakash', (1+2j), True, 100, 20, 30, 40, 50, 60]

# %%
l.pop(2)
# Out:
# 'prakash'

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 100, 20, 30, 40, 50, 60]

# %%
l[3]
# Out:
# True

# %%
l
# Out:
# [34, 5.3, (1+2j), True, 100, 20, 30, 40, 50, 60]

# %%
l.remove(1+2j)

# %%
l
# Out:
# [34, 5.3, True, 100, 20, 30, 40, 50, 60]

# %%
l.reverse()

# %%
l
# Out:
# [60, 50, 40, 30, 20, 100, True, 5.3, 34]

# %%
l.reverse()

# %%
l
# Out:
# [34, 5.3, True, 100, 20, 30, 40, 50, 60]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [34, 5.3, True, 100, 20, 30, 40, 50, 60]
# [100, 20, 25, 30, 40, 50, 60, 10]
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'float'

# %%
l
# Out:
# [True, 5.3, 20, 30, 34, 40, 50, 60, 100]

# %%
l1
# Out:
# [100, 20, 25, 30, 40, 50, 60, 10]

# %%
l1.sort()

# %%
l1
# Out:
# [10, 20, 25, 30, 40, 50, 60, 100]

# %%
l1.sort(reverse= True)
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l3 = [3 , 1, 2 ]
l3
# Out:
# [3, 1, 2]

# %%
l3.sort() # paramteter tunning 
l3
# Out:
# [1, 2, 3]

# %%
l3.sort(reverse=True)
l3
# Out:
# [3, 2, 1]

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2[2]
# Out:
# 'prakash'

# %%
l2
# Out:
# [34, 5.3, 'prakash', (1+2j), True]

# %%
l2[2][0]
# Out:
# 'p'

# %%
print(l2[2][0])
print(l2[2][1])
print(l2[2][2])
print(l2[2][3])
print(l2[2][4])
print(l2[2][5])
# Out:
# p
# r
# a
# k
# a
# s

# %%
l
# Out:
# [True, 5.3, 20, 30, 34, 40, 50, 60, 100]

# %%
for i in l:
    print(i)
# Out:
# True
# 5.3
# 20
# 30
# 34
# 40
# 50
# 60
# 100

# %%
for i in enumerate(l):
    print(i)
# Out:
# (0, True)
# (1, 5.3)
# (2, 20)
# (3, 30)
# (4, 34)
# (5, 40)
# (6, 50)
# (7, 60)
# (8, 100)

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10]

# %%
all(l1)
# Out:
# True

# %%
any(l1)
# Out:
# True

# %%
l1.append(0)

# %%
l1
# Out:
# [100, 60, 50, 40, 30, 25, 20, 10, 0]

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True

# %%
l4 = []

# %%
all(l4)
# Out:
# True

# %%
any(l4)
# Out:
# False

# %%
#
