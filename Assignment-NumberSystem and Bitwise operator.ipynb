# %%
bin(23)
# Out:
# '0b10111'

# %%
int(0b10111)
# Out:
# 23

# %%
oct(32)
# Out:
# '0o40'

# %%
int(0o40)
# Out:
# 32

# %%
hex(30)
# Out:
# '0x1e'

# %%
int(0x1e)
# Out:
# 30

# %%
Bitwise operator

# %%
~13
# Out:
# -14

# %%
12&11
# Out:
# 8

# %%
bin(11)
# Out:
# '0b1011'

# %%
13 | 14
# Out:
# 15

# %%
bin(14)
# Out:
# '0b1110'

# %%
bin(13)
# Out:
# '0b1101'

# %%
13>>2
# Out:
# 3

# %%
13<<2
# Out:
# 52

# %% [markdown]
# 12^13

# %%
12^13
# Out:
# 1
