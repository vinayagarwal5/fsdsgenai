# %%
l=[]
l
# Out:
# []

# %%
l=[1]
l
# Out:
# [1]

# %%
len(l)
# Out:
# 1

# %%
l1 = [10, 20, 30] 
l1
# Out:
# [10, 20, 30]

# %%
l1.append(40)
l1.append(50)

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l1)
# Out:
# 5

# %%
l1.append(34,35)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l1.append(34,35)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l1.append(['a','b','c','d'])

# %% [markdown]
# l1

# %%
l1
# Out:
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]

# %%
l2= [34,7.4,'jivan',(1+2j),True]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [1]
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]
# [34, 7.4, 'jivan', (1+2j), True]

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 1
# 6
# 5

# %%
l1
# Out:
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]

# %%
['a', 'b', 'c','d'] in l1
# Out:
# True

# %%
[10] in l1
# Out:
# False

# %%
l1
# Out:
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]

# %%
l1[:]
# Out:
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]

# %%
l1[:1]
# Out:
# [10]

# %%
l1[:-1]
# Out:
# [10, 20, 30, 40, 50]

# %%
l1[:-3]
# Out:
# [10, 20, 30]

# %%
l1[1:-1]
# Out:
# [20, 30, 40, 50]

# %%
l1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 l1[100]
#
# IndexError: list index out of range

# %%
l1
# Out:
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]

# %%
l1[4:]
# Out:
# [50, ['a', 'b', 'c', 'd']]

# %%
l1[0:10:3]
# Out:
# [10, 40]

# %%
l1[0:10:4]
# Out:
# [10, 50]

# %%
l1[0:20:4]
# Out:
# [10, 50]

# %%
l1[1:20:4]
# Out:
# [20, ['a', 'b', 'c', 'd']]

# %%
l1[::2]
# Out:
# [10, 30, 50]

# %%
l1[::3]
# Out:
# [10, 40]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, ['a', 'b', 'c', 'd']]

# %%
len(l1)
# Out:
# 6

# %%
l1.count(10)
# Out:
# 1

# %%
l1[::-2] ## reverse order
# Out:
# [['a', 'b', 'c', 'd'], 40, 20]
