# %%
t = ()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1= (10,20,30)

# %%
t1
# Out:
# (10, 20, 30)

# %%
t2= (11,14,16,'nit',True,1+2j)

# %%
print(t)
print(t1)
print(t2)
# Out:
# ()
# (10, 20, 30)
# (11, 14, 16, 'nit', True, (1+2j))

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t1.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t1[20]
#
# IndexError: tuple index out of range

# %%
t1[1]
# Out:
# 20

# %%
icici = ('john', 123456, 'cizps')

# %%
icici
# Out:
# ('john', 123456, 'cizps')

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.remove(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 t1.remove(20)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t3= t1 * 3

# %%
t3
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
s = {}

# %%
s
# Out:
# {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {100, 4, 10, 3, 90, 20, 50}

# %%
s1
# Out:
# {3, 4, 10, 20, 50, 90, 100}

# %%
type(s1)
# Out:
# set

# %%
s2 = {3, 1+2j, True, 3.4}

# %%
s2
# Out:
# {(1+2j), 3, 3.4, True}

# %%
print(type(s))
print(type(s1))
print(type(s2))
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'set'>

# %%
s1
# Out:
# {3, 4, 10, 20, 50, 90, 100}

# %%
s1.add(25)

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
s3=s1.copy()

# %%
s3
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
print(s1)
print(s2)
print(s3)
# Out:
# {50, 3, 100, 4, 20, 90, 25, 10}
# {3, True, 3.4, (1+2j)}
# {3, 100, 4, 10, 50, 20, 25, 90}

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 50, 90, 100}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s[0]
#
# KeyError: 0

# %%
s[:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s[:]
#
# KeyError: slice(None, None, None)

# %%
s1[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 s1[:]
#
# TypeError: 'set' object is not subscriptable

# %%
s1.pop()
# Out:
# 50

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 90, 100}

# %%
s1.discard(1000)

# %%
s1
# Out:
# {3, 4, 10, 20, 25, 90, 100}
